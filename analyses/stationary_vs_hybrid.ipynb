# %% [markdown]
# # Simulated/"hybrid" Motion

# %%
from typing import List
from matplotlib import pyplot as plt
import numpy as np

# %%
WASA_THRESHOLD = 0.93
BALANCE_WEIGHTS = True

# %% [markdown]
# ### Comparison: WASA93, ROC AUC, Cohen's Kappa
#
# * WASA93: <u>W</u>ake <u>A</u>ccuracy when <u>S</u>leep <u>A</u>ccuracy is fixed at <u>93%</u>

# %%
from pisces.utils import pad_to_hat, plot_scores_CDF, plot_scores_PDF, add_rocs
from pisces.experiments import split_analysis
from sklearn.metrics import roc_auc_score, roc_curve, cohen_kappa_score

# %%
import matplotlib.pyplot as plt
from pisces.experiments import DataSetObject


sets = DataSetObject.find_data_sets("../data_sets")
walch = sets['walch_et_al']
hybrid = sets['hybrid_motion']

# %% [markdown]
# # Walch et al. data set

# %% [markdown]
# ## (MO) Pretrained UNet evaluation
# We have the trained weights from Mads Olsen et al.'s _ResUNet_ model, saved as a tensorflow lite model with a wrapper for our system. This section calls that on accelerometer recordings in the `'walch_et_al'` data set.

# %%
from pisces.experiments import MOResUNetPretrained, evaluate_mo_on_data_set

# %%
# uses all processors on your CPU to preprocess the accelerometer into spectrograms
# takes ~ 50 sec on M1 Pro (10core)
mo = MOResUNetPretrained(sampling_hz=32)
evaluations_walch, mo_preprocessed_data_walch = evaluate_mo_on_data_set(mo, walch)
mo_aucs_walch = [e["auc"] for e in evaluations_walch.values()]
mo_fprs_walch = [e["roc_curve"]["fprs"] for e in evaluations_walch.values()]
mo_tprs_walch = [e["roc_curve"]["tprs"] for e in evaluations_walch.values()]
# Out:
# parallel_execute: Using 16 of 16 cores (100%) for parallel preprocessing.
# parallel_execute: This can cause memory or heat issues if  is too high; if you run into problems, call prepare_set_for_training() again with max_workers = -1, going more negative if needed. (See the docstring for more info.)
# getting needed X, y for 1360686
# getting needed X, y for 1449548
# getting needed X, y for 1066528
# getting needed X, y for 3509524
# sampling_period_s: 0.020005999999739288
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# getting needed X, y for 2638030
# sampling_period_s: 0.020007999999506865
# getting needed X, y for 1455390
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# sampling_period_s: 0.01501399999960995
# resampling to 32Hz (0.03125s) from 66 Hz (0.01501s)
# sampling_period_s: 0.019860000000335276
# resampling to 32Hz (0.03125s) from 50 Hz (0.01986s)
# getting needed X, y for 46343
# getting needed X, y for 4426783
# getting needed X, y for 1818471
# sampling_period_s: 0.01999199999772827
# resampling to 32Hz (0.03125s) from 50 Hz (0.01999s)
# sampling_period_s: 0.019878999999491498
# resampling to 32Hz (0.03125s) from 50 Hz (0.01988s)
# getting needed X, y for 2598705
# sampling_period_s: 0.019966000000067652
# resampling to 32Hz (0.03125s) from 50 Hz (0.01997s)
# getting needed X, y for 5498603
# sampling_period_s: 0.019756999998207903
# resampling to 32Hz (0.03125s) from 50 Hz (0.01976s)
# sampling_period_s: 0.019988000000012107
# resampling to 32Hz (0.03125s) from 50 Hz (0.01999s)
# getting needed X, y for 4018081
# getting needed X, y for 3997827
# getting needed X, y for 5132496
# sampling_period_s: 0.020012000000008356
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# sampling_period_s: 0.01976999999897089
# resampling to 32Hz (0.03125s) from 50 Hz (0.01977s)
# getting needed X, y for 4314139
# sampling_period_s: 0.015022999999928288
# resampling to 32Hz (0.03125s) from 66 Hz (0.01502s)
# sampling_period_s: 0.01504899999963527
# resampling to 32Hz (0.03125s) from 66 Hz (0.01505s)
# getting needed X, y for 5383425
# sampling_period_s: 0.019675999999890337
# resampling to 32Hz (0.03125s) from 50 Hz (0.01968s)
# sampling_period_s: 0.09990299999844865
# resampling to 32Hz (0.03125s) from 10 Hz (0.09990s)
# sampling_period_s: 0.019981999999799882
# resampling to 32Hz (0.03125s) from 50 Hz (0.01998s)
# getting needed X, y for 5797046
# sampling_period_s: 0.01977700000134064
# resampling to 32Hz (0.03125s) from 50 Hz (0.01978s)
# getting needed X, y for 6220552
# sampling_period_s: 0.01974999999947613
# resampling to 32Hz (0.03125s) from 50 Hz (0.01975s)
# getting needed X, y for 759667
# sampling_period_s: 0.01535399999920628
# resampling to 32Hz (0.03125s) from 65 Hz (0.01535s)
# getting needed X, y for 7749105
# ID 7749105 not found in walch_et_al
# ID 7749105 accelerometer not found in walch_et_al
# getting needed X, y for 781756
# sampling_period_s: 0.01996299999882467
# resampling to 32Hz (0.03125s) from 50 Hz (0.01996s)
# getting needed X, y for 8000685
# sampling_period_s: 0.019951999998738756
# resampling to 32Hz (0.03125s) from 50 Hz (0.01995s)
# getting needed X, y for 8173033
# sampling_period_s: 0.020011000000522472
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# getting needed X, y for 8258170
# sampling_period_s: 0.09988399999929243
# resampling to 32Hz (0.03125s) from 10 Hz (0.09988s)
# getting needed X, y for 844359
# getting needed X, y for 8530312
# sampling_period_s: 0.02000599999996666
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# getting needed X, y for 8686948
# getting needed X, y for 8692923
# getting needed X, y for 9106476
# sampling_period_s: 0.01979399999981979
# resampling to 32Hz (0.03125s) from 50 Hz (0.01979s)
# getting needed X, y for 9618981
# getting needed X, y for 9961348
# sampling_period_s: 0.020027999999911117
# resampling to 32Hz (0.03125s) from 49 Hz (0.02003s)
# sampling_period_s: 0.0200089999998454
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# sampling_period_s: 0.019693000000188476
# resampling to 32Hz (0.03125s) from 50 Hz (0.01969s)
# sampling_period_s: 0.029923999999482476
# resampling to 32Hz (0.03125s) from 33 Hz (0.02992s)
# sampling_period_s: 0.01960600000006707
# resampling to 32Hz (0.03125s) from 51 Hz (0.01961s)
# 1/1 [==============================] - 1s 516ms/step
# Processing 1 of 30 (1066528)... AUROC: 0.5814863102998717
# 1/1 [==============================] - 0s 160ms/step
# Processing 2 of 30 (1360686)... AUROC: 0.5791446820327695
# 1/1 [==============================] - 0s 145ms/step
# Processing 3 of 30 (1449548)... AUROC: 0.7604317851959344
# 1/1 [==============================] - 0s 142ms/step
# Processing 4 of 30 (1455390)... AUROC: 0.7073014050625972
# 1/1 [==============================] - 0s 140ms/step
# Processing 5 of 30 (1818471)... AUROC: 0.9528481012658232
# 1/1 [==============================] - 0s 164ms/step
# Processing 6 of 30 (2598705)... AUROC: 0.7508029978586758
# 1/1 [==============================] - 0s 141ms/step
# Processing 7 of 30 (2638030)... AUROC: 0.8389209164818956
# 1/1 [==============================] - 0s 144ms/step
# Processing 8 of 30 (3509524)... AUROC: 0.8177659961536456
# 1/1 [==============================] - 0s 143ms/step
# Processing 9 of 30 (3997827)... AUROC: 0.9724758842443734
# 1/1 [==============================] - 0s 167ms/step
# Processing 10 of 30 (4018081)... AUROC: 0.9354415274463
# 1/1 [==============================] - 0s 139ms/step
# Processing 11 of 30 (4314139)... AUROC: 0.6381384076833339
# 1/1 [==============================] - 0s 142ms/step
# Processing 12 of 30 (4426783)... AUROC: 0.8875687568756878
# 1/1 [==============================] - 0s 147ms/step
# Processing 13 of 30 (46343)... AUROC: 0.908366331607269
# 1/1 [==============================] - 0s 163ms/step
# Processing 14 of 30 (5132496)... AUROC: 0.8919355972720248
# 1/1 [==============================] - 0s 141ms/step
# Processing 15 of 30 (5383425)... AUROC: 0.9749465240641709
# 1/1 [==============================] - 0s 154ms/step
# Processing 16 of 30 (5498603)... AUROC: 0.9799292830000444
# 1/1 [==============================] - 0s 147ms/step
# Processing 17 of 30 (5797046)... AUROC: 0.7703835781966043
# 1/1 [==============================] - 0s 167ms/step
# Processing 18 of 30 (6220552)... AUROC: 0.811743134913867
# 1/1 [==============================] - 0s 140ms/step
# Processing 19 of 30 (759667)... AUROC: 0.9275097465886943
# 1/1 [==============================] - 0s 144ms/step
# Processing 20 of 30 (781756)... AUROC: 0.844837544156561
# 1/1 [==============================] - 0s 147ms/step
# Processing 21 of 30 (8000685)... AUROC: 0.9024990161353802
# 1/1 [==============================] - 0s 181ms/step
# Processing 22 of 30 (8173033)... AUROC: 0.8905563416995615
# 1/1 [==============================] - 0s 143ms/step
# Processing 23 of 30 (8258170)... AUROC: 0.9446286950252337
# 1/1 [==============================] - 0s 147ms/step
# Processing 24 of 30 (844359)... AUROC: 0.7308083239715406
# 1/1 [==============================] - 0s 142ms/step
# Processing 25 of 30 (8530312)... AUROC: 0.8901035673187547
# 1/1 [==============================] - 0s 162ms/step
# Processing 26 of 30 (8686948)... AUROC: 0.9927918187142406
# 1/1 [==============================] - 0s 144ms/step
# Processing 27 of 30 (8692923)... AUROC: 0.9539834710743813
# 1/1 [==============================] - 0s 149ms/step
# Processing 28 of 30 (9106476)... AUROC: 0.8883359007781331
# 1/1 [==============================] - 0s 156ms/step
# Processing 29 of 30 (9618981)... AUROC: 0.7633917396745898
# 1/1 [==============================] - 0s 160ms/step
# Processing 30 of 30 (9961348)... AUROC: 0.9229143737618308

# %%
plot_scores_PDF(mo_aucs_walch)

add_rocs(mo_fprs_walch, mo_tprs_walch, roc_group_name="MO")

# %% [markdown]
# ### debugging

# %%
import random

from pisces.experiments import MOResUNetPretrained


w = sets['walch_et_al']
(X, y), id  = mo_preprocessed_data_walch[1]
print("X.shape =", X.shape)
spec = X[0, 1:, :, 0].T

print("spec.shape =", spec.shape)
# Out:
# X.shape = (1, 15360, 32, 2)
# spec.shape = (32, 15359)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


def plot_spectrogram(preprocessed_data, idx):
    (X, y), id = preprocessed_data[idx]
    spec = X[0, 1:, :, 0].T

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 8))

    # ax1.imshow(.T)

    img = ax1.imshow(spec, origin="lower", aspect="auto")#, vmin=vmin, vmax=vmax)
    ax1.set_title('Spectrogram, Time : Freq')
    ax1.set_xlabel('Time')
    ax1.set_ylabel('Freq')

    axins = inset_axes(ax1,
                    width="5%",  # width = 5% of parent_bbox width
                    height="75%",  # height : 50%
                    loc='center right')

    plt.colorbar(img, cax=axins, orientation="vertical")

    ax3.plot(spec)
    ax3.set_title('Spectrogram, Frequency : Power ')
    ax3.set_xlabel('Freq')
    ax3.set_ylabel('Power')
    ax3.set_xlim(0, 31)#spec.shape[0])


    ax2.plot(spec.T)
    ax2.set_title('Spectrogram, Time : Power')
    ax2.set_xlabel('Time')
    ax2.set_ylabel('Power')
    ax2.set_xlim(0, spec.shape[1])

    plt.tight_layout(pad=0.3)
    fig.suptitle(f"Subject {id}")
    plt.show()

# %%
def plot_predictions(evaluations, y_time, idx):
    y_pad = evaluations[idx]["y_padded"][:len(y_time)]
    y_pred = evaluations[idx]["y_hat"][:len(y_time)]
    y_mask = evaluations[idx]["mask"][:len(y_time)]

    fig, ax = plt.subplots(figsize=(20, 10))
    ax.plot(y_time, y_pad, label="True")
    ax.plot(y_time, y_pred, label="Predicted")
    ax.plot(y_time, y_mask, label="Mask")
    ax.legend(loc='upper right')

# %%
index = 0
_, id = mo_preprocessed_data_walch[index]
psg = w.get_feature_data("psg", id)
psg_time = psg[:, 0].to_numpy()

plot_spectrogram(mo_preprocessed_data_walch, index)
# broken now that evaluations_walch is a dict
# think we want to just use 
plot_predictions(evaluations=evaluations_walch, y_time=psg_time, idx=id)
# Out:
# /var/folders/h4/pg7xmblx74zbp2yhls4bc_mh0000gn/T/ipykernel_40207/3078200158.py:38: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(pad=0.3)

# %% [markdown]
# ## LOO + SGD Log Reg classifier
# Adding LOOX can be achieved by training on 'walch_et_al' and testing on 'hybrid_data'.

# %%
from pisces.experiments import LeaveOneOutSplitter, SGDLogisticRegression, run_splits

DATA_SET = walch
loo = LeaveOneOutSplitter()

split_models, log_reg_preprocessed_data_walch, splits = run_splits(loo, DATA_SET, SGDLogisticRegression)
# Out:
# ID 7749105 not found in walch_et_al
# 31it [00:02, 10.85it/s]

# %%
from typing import Dict


log_reg_preprocessed_data_walch = [l for l in log_reg_preprocessed_data_walch if l[0] is not None]
log_reg_evaluations_walch: Dict[str, dict] = {}
for i, ((X, y), id) in enumerate(log_reg_preprocessed_data_walch):
    y_hat_proba = split_models[i].predict_probabilities(X)
    y_hat_sleep_proba = y_hat_proba[:, 1].reshape(-1,)
    y_prepped, _ = SGDLogisticRegression()._prepare_labels(y)
    try:
        analysis = split_analysis(y_prepped, y_hat_sleep_proba, balancing=False)
    except ValueError as e:
        print(f"Error processing {id}: {e}")
        continue
    log_reg_evaluations_walch[id] = analysis
    print(f"Processing {i+1} of {len(log_reg_preprocessed_data_walch)} ({id})... AUROC: {analysis['auc']}")
log_reg_aucs_walch = [e["auc"] for e in log_reg_evaluations_walch.values()]
log_reg_fprs_walch = [e["roc_curve"]["fprs"] for e in log_reg_evaluations_walch.values()]
log_reg_tprs_walch = [e["roc_curve"]["tprs"] for e in log_reg_evaluations_walch.values()]
# Out:
# Processing 1 of 30 (1066528)... AUROC: 0.7314095492312315
# Processing 2 of 30 (1360686)... AUROC: 0.5415497517807041
# Processing 3 of 30 (1449548)... AUROC: 0.7652515723270439
# Processing 4 of 30 (1455390)... AUROC: 0.8265009871095101
# Processing 5 of 30 (1818471)... AUROC: 0.890446051838457
# Processing 6 of 30 (2598705)... AUROC: 0.9057697351167059
# Processing 7 of 30 (2638030)... AUROC: 0.8917998163452716
# Processing 8 of 30 (3509524)... AUROC: 0.9222689075630255
# Processing 9 of 30 (3997827)... AUROC: 0.9732642124883497
# Processing 10 of 30 (4018081)... AUROC: 0.8927397876240881
# Processing 11 of 30 (4314139)... AUROC: 0.8821759072056568
# Processing 12 of 30 (4426783)... AUROC: 0.9643240480449791
# Processing 13 of 30 (46343)... AUROC: 0.8685476273119455
# Processing 14 of 30 (5132496)... AUROC: 0.6917647058823526
# Processing 15 of 30 (5383425)... AUROC: 0.9763186221743809
# Processing 16 of 30 (5498603)... AUROC: 0.8523770972334661
# Processing 17 of 30 (5797046)... AUROC: 0.8457959173807386
# Processing 18 of 30 (6220552)... AUROC: 0.8628137065637067
# Processing 19 of 30 (759667)... AUROC: 0.8774944567627494
# Processing 20 of 30 (781756)... AUROC: 0.794914961581625
# Processing 21 of 30 (8000685)... AUROC: 0.8420289855072461
# Processing 22 of 30 (8173033)... AUROC: 0.9476217322308536
# Processing 23 of 30 (8258170)... AUROC: 0.833001277139204
# Processing 24 of 30 (844359)... AUROC: 0.8744342198780555
# Processing 25 of 30 (8530312)... AUROC: 0.89746656378601
# Processing 26 of 30 (8686948)... AUROC: 0.9601883239171375
# Processing 27 of 30 (8692923)... AUROC: 0.8113370874564901
# Processing 28 of 30 (9106476)... AUROC: 0.7835249042145623
# Processing 29 of 30 (9618981)... AUROC: 0.8683236594067849
# Processing 30 of 30 (9961348)... AUROC: 0.9044161813480984
# /Users/eric/Engineering/Work/pisces/pisces/utils.py:409: UserWarning: y_hat is shorter than y by 42 elements, trimming y
#   warnings.warn(f"y_hat is shorter than y by {-pad} elements, trimming y")

# %%
plot_scores_CDF(log_reg_aucs_walch)

# %%
plot_scores_PDF(log_reg_aucs_walch)

# %% [markdown]
# ### Comparision: ROC

# %%
fig, ax = plt.subplots(figsize=(20, 10))
lr_color = "black"
mo_color = "tab:red"

add_rocs(
    fprs=log_reg_fprs_walch, 
    tprs=log_reg_tprs_walch,
    avg_curve_color=lr_color,
    specific_curve_color=lr_color,
    roc_group_name="(LogReg)",
    ax=ax,
    min_auc=0.5,
)

add_rocs(
    fprs=mo_fprs_walch,
    tprs=mo_tprs_walch,
    avg_curve_color=mo_color,
    specific_curve_color=mo_color,
    roc_group_name="(MO)",
    ax=ax,
    min_auc=0.5,
)
ax.legend(loc='lower right')

# %% [markdown]
# # Hybrid data set

# %%
# uses all processors on your CPU to preprocess the accelerometer into spectrograms
# takes ~ 50 sec on M1 Pro (10core)

evaluations_hybrid, mo_preprocessed_data_hybrid = evaluate_mo_on_data_set(mo, hybrid)
mo_aucs_hybrid = [e["auc"] for e in evaluations_hybrid.values()]
mo_fprs_hybrid = [e["roc_curve"]["fprs"] for e in evaluations_hybrid.values()]
mo_tprs_hybrid = [e["roc_curve"]["tprs"] for e in evaluations_hybrid.values()]
# Out:
# parallel_execute: Using 16 of 16 cores (100%) for parallel preprocessing.
# parallel_execute: This can cause memory or heat issues if  is too high; if you run into problems, call prepare_set_for_training() again with max_workers = -1, going more negative if needed. (See the docstring for more info.)
# getting needed X, y for 1066528
# getting needed X, y for 46343
# getting needed X, y for 5383425
# getting needed X, y for 1449548
# getting needed X, y for 1455390
# getting needed X, y for 3509524
# getting needed X, y for 2638030
# getting needed X, y for 4018081
# getting needed X, y for 1360686
# getting needed X, y for 5132496
# sampling_period_s: 0.019965999999840278
# resampling to 32Hz (0.03125s) from 50 Hz (0.01997s)
# getting needed X, y for 4426783
# getting needed X, y for 4314139
# sampling_period_s: 0.09990100000140956
# resampling to 32Hz (0.03125s) from 10 Hz (0.09990s)
# getting needed X, y for 2598705
# getting needed X, y for 1818471
# sampling_period_s: 0.020005999999739288
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# getting needed X, y for 5498603
# getting needed X, y for 3997827
# sampling_period_s: 0.01501300000018091
# resampling to 32Hz (0.03125s) from 66 Hz (0.01501s)
# sampling_period_s: 0.015050999999630221
# resampling to 32Hz (0.03125s) from 66 Hz (0.01505s)
# sampling_period_s: 0.015022999999928288
# resampling to 32Hz (0.03125s) from 66 Hz (0.01502s)
# sampling_period_s: 0.01999199999772827
# resampling to 32Hz (0.03125s) from 50 Hz (0.01999s)
# sampling_period_s: 0.019860000000107902
# resampling to 32Hz (0.03125s) from 50 Hz (0.01986s)
# sampling_period_s: 0.01987800000097195
# sampling_period_s: 0.019755999997869367
# resampling to 32Hz (0.03125s) from 50 Hz (0.01988s)
# resampling to 32Hz (0.03125s) from 50 Hz (0.01976s)
# sampling_period_s: 0.019981999999799882
# sampling_period_s: 0.019988000000012107
# resampling to 32Hz (0.03125s) from 50 Hz (0.01998s)
# resampling to 32Hz (0.03125s) from 50 Hz (0.01999s)
# sampling_period_s: 0.02001199999722303
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# sampling_period_s: 0.020007999999506865
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# sampling_period_s: 0.019673999999213265
# resampling to 32Hz (0.03125s) from 50 Hz (0.01967s)
# sampling_period_s: 0.01976700000159326
# resampling to 32Hz (0.03125s) from 50 Hz (0.01977s)
# getting needed X, y for 5797046
# sampling_period_s: 0.019779999999855136
# resampling to 32Hz (0.03125s) from 50 Hz (0.01978s)
# getting needed X, y for 6220552
# sampling_period_s: 0.019747000000279513
# resampling to 32Hz (0.03125s) from 50 Hz (0.01975s)
# getting needed X, y for 759667
# sampling_period_s: 0.015401000000565546
# resampling to 32Hz (0.03125s) from 64 Hz (0.01540s)
# getting needed X, y for 7749105
# ID 7749105 not found in hybrid_motion
# ID 7749105 accelerometer not found in hybrid_motion
# getting needed X, y for 781756
# sampling_period_s: 0.019962000002124114
# resampling to 32Hz (0.03125s) from 50 Hz (0.01996s)
# getting needed X, y for 8000685
# sampling_period_s: 0.019951999998738756
# resampling to 32Hz (0.03125s) from 50 Hz (0.01995s)
# getting needed X, y for 8173033
# sampling_period_s: 0.020011000000522472
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# getting needed X, y for 8258170
# sampling_period_s: 0.09988300000259187
# resampling to 32Hz (0.03125s) from 10 Hz (0.09988s)
# getting needed X, y for 844359
# getting needed X, y for 8530312
# sampling_period_s: 0.020005999999739288
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# getting needed X, y for 8686948
# sampling_period_s: 0.01979100000062317
# resampling to 32Hz (0.03125s) from 50 Hz (0.01979s)
# sampling_period_s: 0.020027999999001622
# resampling to 32Hz (0.03125s) from 49 Hz (0.02003s)
# getting needed X, y for 8692923
# getting needed X, y for 9106476
# getting needed X, y for 9618981
# getting needed X, y for 9961348
# sampling_period_s: 0.0200089999998454
# resampling to 32Hz (0.03125s) from 49 Hz (0.02001s)
# sampling_period_s: 0.019693000000188476
# resampling to 32Hz (0.03125s) from 50 Hz (0.01969s)
# sampling_period_s: 0.029923999999482476
# resampling to 32Hz (0.03125s) from 33 Hz (0.02992s)
# sampling_period_s: 0.019605000000410655
# resampling to 32Hz (0.03125s) from 51 Hz (0.01961s)
# 1/1 [==============================] - 0s 159ms/step
# Processing 1 of 30 (1066528)... AUROC: 0.6001409492934936
# 1/1 [==============================] - 0s 144ms/step
# Processing 2 of 30 (1360686)... AUROC: 0.5808057432606208
# 1/1 [==============================] - 0s 141ms/step
# Processing 3 of 30 (1449548)... AUROC: 0.8183962264150956
# 1/1 [==============================] - 0s 142ms/step
# Processing 4 of 30 (1455390)... AUROC: 0.734869608003941
# 1/1 [==============================] - 0s 142ms/step
# Processing 5 of 30 (1818471)... AUROC: 0.9945147679324897
# 1/1 [==============================] - 0s 163ms/step
# Processing 6 of 30 (2598705)... AUROC: 0.7627408993576099
# 1/1 [==============================] - 0s 139ms/step
# Processing 7 of 30 (2638030)... AUROC: 0.9033752155703394
# 1/1 [==============================] - 0s 139ms/step
# Processing 8 of 30 (3509524)... AUROC: 0.8932718225171056
# 1/1 [==============================] - 0s 140ms/step
# Processing 9 of 30 (3997827)... AUROC: 0.9757341907824232
# 1/1 [==============================] - 0s 140ms/step
# Processing 10 of 30 (4018081)... AUROC: 0.923994859555718
# 1/1 [==============================] - 0s 150ms/step
# Processing 11 of 30 (4314139)... AUROC: 0.6896037160039495
# 1/1 [==============================] - 0s 138ms/step
# Processing 12 of 30 (4426783)... AUROC: 0.9392621664050235
# 1/1 [==============================] - 0s 140ms/step
# Processing 13 of 30 (46343)... AUROC: 0.9177724821271793
# 1/1 [==============================] - 0s 138ms/step
# Processing 14 of 30 (5132496)... AUROC: 0.951248597081931
# 1/1 [==============================] - 0s 162ms/step
# Processing 15 of 30 (5383425)... AUROC: 0.9724626068376069
# 1/1 [==============================] - 0s 137ms/step
# Processing 16 of 30 (5498603)... AUROC: 0.9743100691031268
# 1/1 [==============================] - 0s 138ms/step
# Processing 17 of 30 (5797046)... AUROC: 0.8395790403296989
# 1/1 [==============================] - 0s 139ms/step
# Processing 18 of 30 (6220552)... AUROC: 0.8211103208802257
# 1/1 [==============================] - 0s 138ms/step
# Processing 19 of 30 (759667)... AUROC: 0.9254801847799662
# 1/1 [==============================] - 0s 148ms/step
# Processing 20 of 30 (781756)... AUROC: 0.8573671076287339
# 1/1 [==============================] - 0s 142ms/step
# Processing 21 of 30 (8000685)... AUROC: 0.8927915518824585
# 1/1 [==============================] - 0s 141ms/step
# Processing 22 of 30 (8173033)... AUROC: 0.9459670812541906
# 1/1 [==============================] - 0s 140ms/step
# Processing 23 of 30 (8258170)... AUROC: 0.7977435035707888
# 1/1 [==============================] - 0s 164ms/step
# Processing 24 of 30 (844359)... AUROC: 0.8542903760766059
# 1/1 [==============================] - 0s 142ms/step
# Processing 25 of 30 (8530312)... AUROC: 0.8717358590776303
# 1/1 [==============================] - 0s 143ms/step
# Processing 26 of 30 (8686948)... AUROC: 0.9870027481191149
# 1/1 [==============================] - 0s 141ms/step
# Processing 27 of 30 (8692923)... AUROC: 0.9706911732335461
# 1/1 [==============================] - 0s 145ms/step
# Processing 28 of 30 (9106476)... AUROC: 0.9122675504353089
# 1/1 [==============================] - 0s 149ms/step
# Processing 29 of 30 (9618981)... AUROC: 0.8056979273445536
# 1/1 [==============================] - 0s 142ms/step
# Processing 30 of 30 (9961348)... AUROC: 0.9476985177629718

# %%
plot_scores_CDF(mo_aucs_hybrid)

# %%
# y so terrible??
# probably timestamp/gap issues
# look at worst ones
plot_scores_PDF(mo_aucs_hybrid)

add_rocs(mo_fprs_hybrid, mo_tprs_hybrid, roc_group_name="MO")

# %%
log_reg_preprocessed_data_hybrid = [
    (d, DATA_SET.ids[i])
    for i in range(len(split_models))
    if (d := split_models[i].get_needed_X_y(DATA_SET, DATA_SET.ids[i])) is not None
]

log_reg_evaluations_hybrid: Dict[str, dict] = {}
for i, ((X, y), id) in enumerate(log_reg_preprocessed_data_hybrid):
    y_hat_proba = split_models[i].predict_probabilities(X)
    y_hat_sleep_proba = y_hat_proba[:, 1].reshape(-1,)
    y_prepped, _ = SGDLogisticRegression()._prepare_labels(y)
    try:
        analysis = split_analysis(y_prepped, y_hat_sleep_proba, balancing=False)
    except ValueError as e:
        print(f"Error processing {id}: {e}")
        continue
    # analysis = split_analysis(y, y_hat_proba)
    log_reg_evaluations_hybrid[id] = analysis
    print(f"Processing {i+1} of {len(log_reg_preprocessed_data_hybrid)} ({id})... AUROC: {analysis['auc']}")
log_reg_aucs_hybrid = [e["auc"] for e in log_reg_evaluations_hybrid.values()]
log_reg_fprs_hybrid = [e["roc_curve"]["fprs"] for e in log_reg_evaluations_hybrid.values()]
log_reg_tprs_hybrid = [e["roc_curve"]["tprs"] for e in log_reg_evaluations_hybrid.values()]
# Out:
# ID 7749105 not found in walch_et_al
# Processing 1 of 29 (1066528)... AUROC: 0.7314095492312315
# Processing 2 of 29 (1360686)... AUROC: 0.5415497517807041
# Processing 3 of 29 (1449548)... AUROC: 0.7652515723270439
# Processing 4 of 29 (1455390)... AUROC: 0.8265009871095101
# Processing 5 of 29 (1818471)... AUROC: 0.890446051838457
# Processing 6 of 29 (2598705)... AUROC: 0.9057697351167059
# Processing 7 of 29 (2638030)... AUROC: 0.8917998163452716
# Processing 8 of 29 (3509524)... AUROC: 0.9222689075630255
# Processing 9 of 29 (3997827)... AUROC: 0.9732642124883497
# Processing 10 of 29 (4018081)... AUROC: 0.8927397876240881
# Processing 11 of 29 (4314139)... AUROC: 0.8821759072056568
# Processing 12 of 29 (4426783)... AUROC: 0.9643240480449791
# Processing 13 of 29 (46343)... AUROC: 0.8685476273119455
# Processing 14 of 29 (5132496)... AUROC: 0.6917647058823526
# Processing 15 of 29 (5383425)... AUROC: 0.9763186221743809
# Processing 16 of 29 (5498603)... AUROC: 0.8523770972334661
# Processing 17 of 29 (5797046)... AUROC: 0.8457959173807386
# Processing 18 of 29 (6220552)... AUROC: 0.8628137065637067
# Processing 19 of 29 (759667)... AUROC: 0.8774944567627494
# Processing 20 of 29 (781756)... AUROC: 0.794914961581625
# Processing 21 of 29 (8000685)... AUROC: 0.8420289855072461
# Processing 22 of 29 (8173033)... AUROC: 0.9476217322308536
# Processing 23 of 29 (8258170)... AUROC: 0.833001277139204
# Processing 24 of 29 (844359)... AUROC: 0.8744342198780555
# Processing 25 of 29 (8530312)... AUROC: 0.89746656378601
# Processing 26 of 29 (8686948)... AUROC: 0.9601883239171375
# Processing 27 of 29 (8692923)... AUROC: 0.8113370874564901
# Processing 28 of 29 (9106476)... AUROC: 0.7835249042145623
# Processing 29 of 29 (9618981)... AUROC: 0.8683236594067849
# /Users/eric/Engineering/Work/pisces/pisces/utils.py:409: UserWarning: y_hat is shorter than y by 42 elements, trimming y
#   warnings.warn(f"y_hat is shorter than y by {-pad} elements, trimming y")

# %%
plot_scores_CDF(log_reg_aucs_hybrid)

# %%
plot_scores_PDF(log_reg_aucs_hybrid)

# %% [markdown]
# ### Comparision ROC

# %%
fig, ax = plt.subplots(figsize=(20, 10))
add_rocs(
    fprs=log_reg_fprs_hybrid,
    tprs=log_reg_tprs_hybrid,
    # min_auc=0.7, 
    avg_curve_color=lr_color,
    specific_curve_color=lr_color,
    roc_group_name="(LogReg)",
    ax=ax,
)

add_rocs(
    fprs=mo_fprs_hybrid,
    tprs=mo_tprs_hybrid,
    avg_curve_color=mo_color,
    specific_curve_color=mo_color,
    # min_auc=0.7,
    roc_group_name="(MO)",
    ax=ax
)
ax.legend(loc='lower right')

# %%
log_reg_wasa_93_hybrid = [e[f"wasa93"] for e in log_reg_evaluations_hybrid.values()]
mo_wasa_93_hybrid = [e[f"wasa93"] for e in evaluations_hybrid.values()]
log_reg_kappa_hybrid = [e["kappa"] for e in log_reg_evaluations_hybrid.values()]
mo_kappa_hybrid = [e["kappa"] for e in evaluations_hybrid.values()]


log_reg_wasa_93_walch = [e[f"wasa93"] for e in log_reg_evaluations_walch.values()]
mo_wasa_93_walch = [e[f"wasa93"] for e in evaluations_walch.values()]
log_reg_kappa_walch = [e["kappa"] for e in log_reg_evaluations_walch.values()]
mo_kappa_walch = [e["kappa"] for e in evaluations_walch.values()]

plot_titles = [
    f"WASA{int(WASA_THRESHOLD*100)}",
    "Kappa",
    "AUROC",
]
hybrid_data_to_plot = [
    (log_reg_wasa_93_hybrid, mo_wasa_93_hybrid),
    (log_reg_kappa_hybrid, mo_kappa_hybrid),
    (log_reg_aucs_hybrid, mo_aucs_hybrid),
]

walch_data_to_plot = [
    (log_reg_wasa_93_walch, mo_wasa_93_walch),
    (log_reg_kappa_walch, mo_kappa_walch),
    (log_reg_aucs_walch, mo_aucs_walch),
]

ncol = 3
fig_lr, ax_lr = plt.subplots(nrows=2, ncols=ncol, figsize=(20, 10))
fig_mo, ax_mo = plt.subplots(nrows=2, ncols=ncol, figsize=(20, 10))

fig_lr.suptitle("Logistic Regression")
fig_mo.suptitle("Mads Olsen")


for i, pair in enumerate(walch_data_to_plot):
    lr, mo = pair
    plot_scores_PDF(lr, ax=ax_lr[0, i])
    plot_scores_PDF(mo, ax=ax_mo[0, i])

    ax_lr[0, i].set_title(plot_titles[i])
    ax_mo[0, i].set_title(plot_titles[i])
    ax_lr[0, i].legend()
    ax_mo[0, i].legend()

for i, pair in enumerate(hybrid_data_to_plot):
    lr, mo = pair
    plot_scores_PDF(lr, ax=ax_lr[1, i])
    plot_scores_PDF(mo, ax=ax_mo[1, i])

    ax_lr[1, i].legend()
    ax_mo[1, i].legend()

for ax_set in [ax_lr, ax_mo]:
    for i in range(ncol):
        for j in range(2):
            ax_set[j, i].set_ylim(0, 7)

# %%
acc_mean_gaps = []
acc_median_gaps = []
excludes = []
for id in walch.ids:
    psg = walch.get_feature_data("psg", id)
    acc = walch.get_feature_data("accelerometer", id)
    if psg is None or acc is None:
        excludes.append(id)
        continue

    psg_time = psg[:, 0].to_numpy()
    acc_time = acc[:, 0].to_numpy()
    acc_mean_gap = np.mean(np.diff(acc_time))
    acc_median_gap = np.median(np.diff(acc_time))

    acc_mean_gaps.append(acc_mean_gap)
    acc_median_gaps.append(acc_median_gap)
    # print(f"ID: {id}, mean gap: {acc_mean_gap}, median gap: {acc_median_gap}")
    if acc_mean_gap > 0.04:
        print(f"!!!!!ID: {id}, mean gap: {acc_mean_gap}, median gap: {acc_median_gap}")
        excludes.append(id)
# Out:
# !!!!!ID: 5383425, mean gap: 0.09995511555394894, median gap: 0.09990299999844865
# ID 7749105 not found in walch_et_al
# !!!!!ID: 8258170, mean gap: 0.09989854006413004, median gap: 0.09988399999929243
